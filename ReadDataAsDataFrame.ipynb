# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitap60/Data-Analytics/blob/main/ReadDataAsDataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import library
import pandas as pd

# %%
#read comma separated value (csv) file
titanic_csv=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv')

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv

# %%
titanic_csv.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#read semicolon separated (csv) file
titanic_semicolon=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic%20Semicolon.csv',sep=';')

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic%20Semicolon.csv

# %%
titanic_semicolon.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           0       1         1
# 1           1       1         1
# 2           2       1         0
# 3           3       1         0
# 4           4       1         0
#
#                                               name     sex    age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.00      0
# 1                   Allison, Master. Hudson Trevor    male   0.92      1
# 2                     Allison, Miss. Helen Loraine  female   2.00      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.00      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  211.3375       B5        S    2    NaN
# 1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      2  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
#read text file
titanic_txt=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.txt')

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.txt

# %%
titanic_txt.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#read excel file
titanic_excel=pd.read_excel('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.xlsx',sheet_name=0)

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.xlsx

# %%
titanic_excel.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#read json file
titanic_json=pd.read_json('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.json')

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.json

# %%
titanic_json.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0    29      0      0   24160  211.3375       B5        S    2
# 1  0.92      1      2  113781    151.55  C22 C26        S   11
# 2     2      1      2  113781    151.55  C22 C26        S
# 3    30      1      2  113781    151.55  C22 C26        S       135
# 4    25      1      2  113781    151.55  C22 C26        S
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# ...
